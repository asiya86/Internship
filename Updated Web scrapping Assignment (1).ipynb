# %%
#importing necessary libraries
import selenium
import pandas as pd
from bs4 import BeautifulSoup
import time

#Importing requests
import requests

# importing regex
import re

# Importing selenium webdriver
from selenium import webdriver

# Importing required Exceptions
from selenium.common.exceptions import StaleElementReferenceException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.support.ui import WebDriverWait
import warnings
warnings.filterwarnings("ignore")
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC

# %% [markdown]
# # 1. Scrape the details of most viewed videos on YouTube from Wikipedia.

# %%
# Let's first connect

driver=webdriver.Chrome(r"/Users/asiya/Desktop/chromedriver\ 4\\chromedriver.exe")

# %% [markdown]
# ### getting the specified url
# url = "https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos"
# driver.get(url)
# time.sleep(3)

# %%
#Creating empty list
Rank = []
Name = []
Artist = []
Upload_date = []
Views = []

# %%
#Scraping data of rank details
try:
    for i in driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter']//tbody//tr//td[1]")[:30]:
        Rank.append(i.text)
except NoSuchElementException:
    Rank.append('-')

# %%
#Scraping data of video names
try:
    for i in driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter']//tbody//tr//td[2]")[:30]:
        Name.append(i.text)
except NoSuchElementException:
    Name.append('-')

# %%
#Scraping data of artist name
try:
    for i in driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter']//tbody//tr//td[3]")[:30]:
        Artist.append(i.text)
except NoSuchElementException:        
    Artist.append('-')

# %%
#Scraping data of upload dates
try:
    for i in driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter']//tbody//tr//td[5]")[:30]:
        Upload_date.append(i.text)
except NoSuchElementException:        
    Upload_date.append('-')

# %%
#Scraping data of views
try:
    for i in driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter']//tbody//tr//td[4]")[:30]:
        Views.append(i.text)
except NoSuchElementException:
    Views.append('-')

# %%
#DATA FRAMING
Youtube=pd.DataFrame({})
Youtube['Rank'] = Rank
Youtube['Name'] = Name
Youtube['Artist'] = Artist
Youtube['Uploaded Date'] = Upload_date
Youtube['Views'] = Views

# %%
#Printing data frame
Youtube
# Out:
#    Rank                                             Name  \
# 0    1.                            "Baby Shark Dance"[4]
# 1    2.                                   "Despacito"[7]
# 2    3.                       "Johny Johny Yes Papa"[14]
# 3    4.                                  "Bath Song"[15]
# 4    5.                               "Shape of You"[16]
# 5    6.                              "See You Again"[18]
# 6    7.                "Phonics Song with Two Words"[23]
# 7    8.                          "Wheels on the Bus"[24]
# 8    9.                                "Uptown Funk"[25]
# 9   10.  "Learning Colors – Colorful Eggs on a Farm"[26]
# 10  11.                              "Gangnam Style"[27]
# 11  12.   "Masha and the Bear – Recipe for Disaster"[32]
# 12  13.                             "Dame Tu Cosita"[33]
# 13  14.                                      "Sugar"[34]
# 14  15.                                       "Roar"[35]
# ...

# %% [markdown]
# # 2. Scrape the details team India’s international fixtures from bcci.tv. Url = https://www.bcci.tv/.¶
# You need to find following details:
#
# A) Match title (I.e. 1st ODI)
#
# B) Series
#
# C) Place
#
# D) Date
#
# E) Time
#
# Note: - From bcci.tv home page you have reach to the international fixture page through code.

# %%
#getting the specified url
url = "https://www.bcci.tv/"
driver.get(url)
time.sleep(3)

# %%
#Getting url for international fixture and clicking on it
Options_btn = driver.find_element(By.XPATH,'/html/body/nav/div[1]/button/span[2]').click()

# %%
#Getting url for international fixture and clicking on it
Options_btn = driver.find_element(By.XPATH,'/html/body/nav/div[1]/div[2]/ul[1]/li[2]/a').click()

# %%
#Getting url for team India and clicking on it
Options_btn = driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div/div/div/div[2]/div[2]/div/div[4]/div/div[2]/div[5]').click()

# %%
#creating empty lists
Match_title=[]
Series=[]
Place=[]
Date=[]
Time=[]

# %%
# Scrapping Match Titles and place tags
try:
    for i in driver.find_elements(By.XPATH,"//div[@class='fix-place ng-binding ng-scope']"):
        Match_title.append(i.text)
except NoSuchElementException:
    Match_title.append('-')

# %%
#scraping series from series tags

try:
    for i in driver.find_elements(By.XPATH,"//div[@class='fixture-card-mid d-flex align-items-center justify-content-between']"):
        Series.append(i.text)
except NoSuchElementException:
    Series.append('-')

# %%
#scraping date from date tags

try:
    for i in driver.find_elements(By.XPATH,"//h5[@class='ng-binding']"):
        Date.append(i.text)
except NoSuchElementException:
    Date.append('-')

# %%
#scraping time from time tags

try:
    for i in driver.find_elements(By.XPATH,"//h5[@class='text-right ng-binding']"):
        Time.append(i.text)
except NoSuchElementException:
    Time.append('-')

# %%
#creating a dataframe

bcci_fixtures=pd.DataFrame({})
bcci_fixtures['Match_title']=Match_title
bcci_fixtures['Series']=Series
bcci_fixtures['Date']=Date
bcci_fixtures['Time']=Time

# %%
bcci_fixtures
# Out:
#                                          Match_title                Series  \
# 0  1st Test - Vidarbha Cricket Association Stadiu...  India\nvs\nAustralia
# 1             2nd Test - Arun Jaitley Stadium, Delhi  India\nvs\nAustralia
# 2  3rd Test - Himachal Pradesh Cricket Associatio...  India\nvs\nAustralia
# 3        4th Test - Narendra Modi Stadium, Ahmedabad  India\nvs\nAustralia
# 4                 1st ODI - Wankhede Stadium, Mumbai  India\nvs\nAustralia
# 5  2nd ODI - Dr YS Rajasekhara Reddy ACA-VDCA Cri...  India\nvs\nAustralia
# 6          3rd ODI - MA Chidambaram Stadium, Chennai  India\nvs\nAustralia
#
#           Date         Time
# 0   9 FEB 2023  9:30 AM IST
# 1  17 FEB 2023  9:30 AM IST
# 2   1 MAR 2023  9:30 AM IST
# 3   9 MAR 2023  9:30 AM IST
# 4  17 MAR 2023  1:30 PM IST
# 5  19 MAR 2023  1:30 PM IST
# 6  22 MAR 2023  1:30 PM IST

# %% [markdown]
# # 3. Scrape the details of State-wise GDP of India from statisticstime.com

# %%
url_4="http://statisticstimes.com/"

# %%
driver.get(url_4)

# %%
#Clicking on economy section
economy = driver.find_element(By.XPATH,"//div[@class='navbar']//div[2]//button").click()

urls = driver.find_element(By.XPATH,"//div[@class='dropdown-content']//a[3]")
ineco_page = urls.get_attribute("href")
#Going to indian economy page
driver.get(ineco_page)  
time.sleep(5)

# %%
#Creating empty list
Rank = []
State = []
GSDP_1 = []
GSDP_2 = []
Share = []
GDP = []

# %%
#scraping time from time tags

try:
    for i in driver.find_elements(By.XPATH,"//h5[@class='text-right ng-binding']"):
        Time.append(i.text)
except NoSuchElementException:
    Time.append('-')

# %%
#get the url of page containing GDP of indian states
sta_GDP = driver.find_element(By.XPATH,"//ul[@style='list-style-type:none;margin-left:20px;']/li/a")
GDP_url = sta_GDP.get_attribute("href")

driver.get(GDP_url)
time.sleep(6)

# %%
#Scraping data of rank

try:
    for i in driver.find_elements(By.XPATH,"//div[@id='table_id_wrapper']//tbody//tr//td[1]"):
        Rank.append(i.text)
except NoSuchElementException:
    Rank.append('-')

# %%
len(Rank)
# Out:
# 33

# %%
#Scraping data of rank

try:
    for i in driver.find_elements(By.XPATH,"//div[@id='table_id_wrapper']//tbody//tr//td[1]"):
        Rank.append(i.text)
except NoSuchElementException:
    Rank.append('-')

# %%
#Scraping data of State

try:
    for i in driver.find_elements(By.XPATH,"//div[@id='table_id_wrapper']//tbody//tr//td[2]"):
        State.append(i.text)
except NoSuchElementException:
    State.append('-')

# %%
len(State)
# Out:
# 33

# %%
#Scraping data of GSDP_1

try:
    for i in driver.find_elements(By.XPATH,"//div[@id='table_id_wrapper']//tbody//tr//td[3]"):
        GSDP_1.append(i.text)
except NoSuchElementException:
    GSDP_1.append('-')

# %%
len(GSDP_1)
# Out:
# 33

# %%
#Scraping data of GSDP_2

try:
    for i in driver.find_elements(By.XPATH,"//div[@id='table_id_wrapper']//tbody//tr//td[4]"):
        GSDP_2.append(i.text)
except NoSuchElementException:
    GSDP_2.append('-')

# %%
len(GSDP_2)
# Out:
# 33

# %%
#Scraping data of Share

try:
    for i in driver.find_elements(By.XPATH,"//div[@id='table_id_wrapper']//tbody//tr//td[5]"):
        Share.append(i.text)
except NoSuchElementException:
    Share.append('-')

# %%
len(Share)
# Out:
# 33

# %%
#Scraping data of Share

try:
    for i in driver.find_elements(By.XPATH,"//div[@id='table_id_wrapper']//tbody//tr//td[6]"):
        GDP.append(i.text)
except NoSuchElementException:
    GDP.append('-')

# %%
len(GDP)
# Out:
# 33

# %%
#DATA FRAMING
StatisticsTime=pd.DataFrame({})
StatisticsTime['Rank'] = Rank
StatisticsTime['State'] = State
StatisticsTime['GSDP at current price (19-20)'] = GSDP_1
StatisticsTime['GSDP at current price (18-19)'] = GSDP_2
StatisticsTime['Share(18-19)'] = Share
StatisticsTime['GDP($ billion)'] = GDP

# %%
#Printing the data frame
StatisticsTime
# Out:
#    Rank                      State GSDP at current price (19-20)  \
# 0     1                Maharashtra                             -
# 1     2                 Tamil Nadu                     1,845,853
# 2     3              Uttar Pradesh                     1,687,818
# 3     4                    Gujarat                             -
# 4     5                  Karnataka                     1,631,977
# 5     6                West Bengal                     1,253,832
# 6     7                  Rajasthan                     1,020,989
# 7     8             Andhra Pradesh                       972,782
# 8     9                  Telangana                       969,604
# 9    10             Madhya Pradesh                       906,672
# 10   11                     Kerala                             -
# 11   12                      Delhi                       856,112
# 12   13                    Haryana                       831,610
# ...

# %% [markdown]
# # Q4.Scrape the details of trending repositories on Github.com. Url = https://github.com/
# You have to find the following details: A) Repository title
#
# B) Repository description C) Contributors count
#
# D) Language used

# %%
url =  'https://github.com/'
driver.get(url)

# %%
explore = driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/header/div/div[1]/div[2]/button/span/span/div[3]')       # Locating page foe top videos by xpath
explore.click()

# %%
trending = driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/header/div/div[2]/div/nav/ul/li[3]/div/ul[3]/li[3]/a')       # Locating page foe top videos by xpath
trending.click()

# %%
#creating empty lists

Repository_title=[]
Repository_description=[]
Contributors_count=[]
Language_used=[]

# %%
#Scraping Repository_title
try:
    for i in driver.find_elements(By.XPATH,"//h1[@class='h3 lh-condensed']/a"):
        Repository_title.append(i.text)
except NoSuchElementException:
    Repository_title.append('-')

# %%
Repository_title
# Out:
# ['LAION-AI / Open-Assistant',
#  'acheong08 / ChatGPT',
#  'nostr-protocol / nostr',
#  'damus-io / damus',
#  'microsoft / BioGPT',
#  'waylaidwanderer / node-chatgpt-api',
#  'yt-dlp / yt-dlp',
#  'transitive-bullshit / chatgpt-api',
#  'Datalux / Osintgram',
#  'microsoft / PowerToys',
#  'AutumnWhj / ChatGPT-wechat-bot',
#  'coolsnowwolf / lede',
#  'Cameri / nostream',
#  'hikari-no-yume / touchHLE',
#  'ToolJet / ToolJet',
#  'Zero6992 / chatGPT-discord-bot',
#  'adrianhajdin / project_hoobank',
#  'dudykr / stc',
#  'misskey-dev / misskey',
#  'servo / servo',
#  'daveshap / raven',
#  'innnky / so-vits-svc',
#  'LeagueOfPoro / CapsuleFarmerEvolved',
#  'hwchase17 / langchain',
#  'A-poc / RedTeam-Tools']

# %%
#Scraping Repository_description
try:
    for i in driver.find_elements(By.XPATH,"//p[@class='col-9 color-fg-muted my-1 pr-4']"):
        Repository_description.append(i.text)
except NoSuchElementException:
    Repository_description.append('-')

# %%
Repository_description
# Out:
# ['OpenAssistant is a chat-based assistant that understands tasks, can interact with third-party systems, and retrieve information dynamically to do so.',
#  'Reverse engineered ChatGPT API',
#  'a truly censorship-resistant alternative to Twitter that has a chance of working',
#  'iOS nostr client',
#  "A ChatGPT implementation using the official ChatGPT model via OpenAI's API.",
#  'A youtube-dl fork with additional features and fixes',
#  'Node.js client for the unofficial ChatGPT API. 🔥',
#  'Osintgram is a OSINT tool on Instagram. It offers an interactive shell to perform analysis on Instagram account of any users by its nickname',
#  'Windows system utilities to maximize productivity',
#  'ChatGPT for wechat https://github.com/AutumnWhj/ChatGPT-wechat-bot',
#  "Lean's LEDE source",
#  'A Nostr Relay written in TypeScript',
#  'High-level emulator for iPhone OS apps',
# ...

# %% [markdown]
# # Tried to get te contributor. Not able to get contributor. Tried with all possible combination.

# %%
#finding all the Contributors_count


try:
    for i in driver.find_elements(By.XPATH,'//h2[@class="h4 mb-3"]'):
        Contributors_count.append(i.text)
except NoSuchElementException:
    Contributors_count.append('-')

# %%
Contributors_count
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Releases 46',
#  'v0.0.1-beta26\nLatest\n6 hours agoFeb 5, 2023',
#  '+ 45 releases',
#  'Packages 4',
#  'open-assistant/oasst-postgres',
#  'open-assistant/oasst-backend',
#  'open-assistant/oasst-web',
#  'Contributors 117',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '+ 106 contributors',
#  'Python\n68.9%',
#  'TypeScript\n28.5%',
#  'JavaScript\n1.9%',
#  'Shell\n0.6%',
#  'CSS\n0.1%',
#  'Mako\n0.0%',
#  '',
#  'Releases 46',
#  'Packages 4',
#  'Contributors 117',
#  'Languages',
#  'Releases 46',
#  'Packages 4',
#  'Contributors 117',
#  'Languages']

# %%
#finding all the language tags

try:
    for i in driver.find_elements(By.XPATH,"//span[@itemprop='programmingLanguage']"):
        Language_used.append(i.text)
except NoSuchElementException:
    Language_used.append('-')

# %%
Language_used
# Out:
# ['Python',
#  'Python',
#  'Swift',
#  'Python',
#  'JavaScript',
#  'Python',
#  'TypeScript',
#  'Python',
#  'C#',
#  'TypeScript',
#  'C',
#  'TypeScript',
#  'Rust',
#  'JavaScript',
#  'Python',
#  'JavaScript',
#  'Rust',
#  'TypeScript',
#  'Python',
#  'Python',
#  'Python',
#  'Python']

# %%
#printing lengths
print(len(Repository_title),len(Repository_description),len(Language_used))
# Out:
# 25 25 25

# %%
# Adding - for missing values
Repository_description.extend(["-"])

# %%
# Adding - for missing values
Language_used.extend(["-","-","-"])

# %%
#creating a dataframe

Github=pd.DataFrame({})
Github['Repository_title']=Repository_title[:25]
Github['Repository_description']=Repository_description[:25]
Github['Language_used']=Language_used[:25]

# %%
Github
# Out:
#                        Repository_title  \
# 0             LAION-AI / Open-Assistant
# 1                   acheong08 / ChatGPT
# 2                nostr-protocol / nostr
# 3                      damus-io / damus
# 4                    microsoft / BioGPT
# 5    waylaidwanderer / node-chatgpt-api
# 6                       yt-dlp / yt-dlp
# 7     transitive-bullshit / chatgpt-api
# 8                   Datalux / Osintgram
# 9                 microsoft / PowerToys
# 10       AutumnWhj / ChatGPT-wechat-bot
# 11                  coolsnowwolf / lede
# 12                    Cameri / nostream
# 13            hikari-no-yume / touchHLE
# 14                    ToolJet / ToolJet
# 15       Zero6992 / chatGPT-discord-bot
# 16       adrianhajdin / project_hoobank
# 17                         dudykr / stc
# 18                misskey-dev / misskey
# 19                        servo / servo
# 20                     daveshap / raven
# 21                 innnky / so-vits-svc
# ...

# %% [markdown]
# # 5. Scrape the details of top 100 songs on billiboard.com.

# %%
# Let's first connect

driver=webdriver.Chrome(r"/Users/asiya/Desktop/chromedriver\ 4\\chromedriver.exe")

# %%
#specifying the url of the webpage to be scraped
url="https://www.billboard.com/"

# %%
#opening the webpage through our driver
driver.get(url)

# %%
driver.find_element(By.XPATH,'/html/body/div[3]/div[9]/div/div/div/ul/li[1]/ul/li[2]/a').click()

# %%
#creating empty lists
Song_name=[]
Artist_name=[]
Last_week_rank=[]
Peak_rank=[]
Weeks_on_board=[]

# %%
# Scrapping the Song_name

try:
    son = driver.find_elements(By.XPATH,'//li[@class="lrv-u-width-100p"]//h3')
    for i in son:
        Song_name.append(i.text)
except NoSuchElementException:
    Song_name.append("-")

# %%
Song_name
# Out:
# ['Flowers',
#  'Kill Bill',
#  'Anti-Hero',
#  "Creepin'",
#  'Unholy',
#  "I'm Good (Blue)",
#  'Die For You',
#  'Rich Flex',
#  'As It Was',
#  'Golden Hour',
#  'Something In The Orange',
#  'Just Wanna Rock',
#  'Bzrp Music Sessions, Vol. 53',
#  'Made You Look',
#  'Cuff It',
#  'Under The Influence',
#  'Bad Habit',
#  'Thank God',
#  'Rock And A Hard Place',
#  'You Proof',
#  'Superhero (Heroes & Villains)',
#  'Escapism',
#  'Wait In The Truck',
#  'I Like You (A Happier Song)',
#  'Going, Going, Gone',
#  'Shirt',
#  'Thought You Should Know',
#  'Calm Down',
#  'Until I Found You',
#  'Lavender Haze',
#  'Snooze',
#  'Bebe Dame',
#  'Heart Like A Truck',
#  'Wait For U',
#  'The Kind Of Love We Make',
#  'Super Freaky Girl',
#  'Tomorrow 2',
#  'Nobody Gets Me',
#  'Sure Thing',
#  'What My World Spins Around',
#  'She Had Me At Heads Carolina',
#  'Sunroof',
#  'Unstoppable',
#  'Lift Me Up',
#  "I Ain't Worried",
#  'Whiskey On You',
#  'Low',
#  'About Damn Time',
# ...

# %%
# Scrapping the Artist_name

try:
    Artist = driver.find_elements(By.XPATH,'//li[@class="o-chart-results-list__item"]')
    for i in Artist:
        Artist_name.append(i.text)
except NoSuchElementException:
    Artist_name.append("-")

# %%
 Artist_name
# Out:
# []

# %%
# Scrapping the Last week Rank

try:
    rank = driver.find_elements(By.XPATH,'//li[@class="lrv-u-width-100p"]/ul/li[4]/span[1]')
    for i in rank:
        Last_week_rank.append(i.text)
except NoSuchElementException:
    Last_week_rank.append("-")

# %%
Last_week_rank
# Out:
# ['1',
#  '2',
#  '3',
#  '4',
#  '5',
#  '6',
#  '7',
#  '8',
#  '10',
#  '11',
#  '13',
#  '16',
#  '9',
#  '15',
#  '17',
#  '14',
#  '12',
#  '19',
#  '21',
#  '20',
#  '18',
#  '22',
#  '37',
#  '24',
#  '26',
#  '23',
#  '31',
#  '35',
#  '28',
#  '34',
#  '32',
#  '25',
#  '33',
#  '27',
#  '38',
#  '29',
#  '30',
#  '36',
#  '42',
#  '40',
#  '44',
#  '41',
#  '43',
#  '39',
#  '45',
#  '51',
#  '46',
#  '49',
#  '54',
#  '48',
#  '50',
#  '-',
#  '53',
#  '57',
#  '60',
#  '75',
#  '52',
#  '63',
#  '58',
#  '66',
#  '70',
#  '69',
#  '71',
#  '-',
#  '62',
#  '64',
#  '61',
#  '67',
#  '72',
#  '79',
#  '77',
#  '-',
#  '82',
#  '73',
#  '78',
#  '68',
#  '99',
#  '74',
#  '91',
#  '65',
#  '-',
#  '-',
#  '98',
#  '-',
#  '80',
#  '-',
#  '81',
#  '92',
#  '85',
#  '-',
#  '-',
#  '-',
#  '84',
#  '97',
#  '94',
#  '-',
#  '96',
#  '-',
#  '89',
#  '-']

# %%
# Scrapping the Peak_rank

try:
    Peak_rank = driver.find_elements(By.XPATH,'//li[@class="o-chart-results-list__item"]')
    for i in  Peak_rank:
        Peak_rank.append(i.text)
except NoSuchElementException:
    Peak_rank.append("-")

# %%
 Peak_rank
# Out:
# []

# %% [markdown]
# Unable to find peak_rank

# %%
# Scrapping the Weeks_on_board

try:
    Weeks = driver.find_elements(By.XPATH,'//span[@class="c-label  a-font-primary-bold-l a-font-primary-m@mobile-max u-font-weight-normal@mobile-max lrv-u-padding-tb-050@mobile-max u-font-size-32@table"]')
    for i in Weeks:
        Weeks_on_board.append(i.text)
except NoSuchElementException:
    Weeks_on_board.append("-")

# %%
Weeks_on_board
# Out:
# []

# %% [raw]
# # Only was able to pull song name and last week chart. No other info I was able to pull. Tried multiple method

# %% [markdown]
# # 6. Scrape the details of Highest sellingnovels¶

# %%
url_6="https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare"

# %%
driver.get(url_6)

# %%
Book= []
Author = []
Volumes = []
Publisher = []
Genre = []

# %%
for i in range(1,101):
    try:
        Book_tag = driver.find_element(By.XPATH,f"/html/body/div/div[2]/div[2]/div/div[2]/div/table/tbody/tr[{i}]/td[2]")
        Book.append(Book_tag.text)
    except NoSuchElementException:
        Book.append("-")
        
for i in range(1,101):
    try:
        Author_tag = driver.find_element(By.XPATH,f"/html/body/div/div[2]/div[2]/div/div[2]/div/table/tbody/tr[{i}]/td[3]")
        Author.append(Author_tag.text)
    except NoSuchElementException:
        Author.append("-")
        
for i in range(1,101):
    try:
        Volumes_tag = driver.find_element(By.XPATH,f"/html/body/div/div[2]/div[2]/div/div[2]/div/table/tbody/tr[{i}]/td[4]")
        Volumes.append(Volumes_tag.text)
    except NoSuchElementException:
        Volumes.append("-")

for i in range(1,101):
    try:
        Publisher_tag = driver.find_element(By.XPATH,f"/html/body/div/div[2]/div[2]/div/div[2]/div/table/tbody/tr[{i}]/td[5]")
        Publisher.append(Publisher_tag.text)
    except NoSuchElementException:
        Publisher.append("-")

for i in range(1,101):
    try:
        Genre_tag = driver.find_element(By.XPATH,f"/html/body/div/div[2]/div[2]/div/div[2]/div/table/tbody/tr[{i}]/td[6]")
        Genre.append(Genre_tag.text)
    except NoSuchElementException:
        Genre.append("-")

# %%
Top100Books = {'Book name': Book,'Author name':Author,'Volumes sold':Volumes,'Publisher':Publisher,'Genre':Genre}

Top100BooksDF = pd.DataFrame(Top100Books)

Top100BooksDF
# Out:
#                                             Book name       Author name  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volumes sold        Publisher                        Genre
# ...

# %% [markdown]
# # Question no 7 is after question 8

# %% [markdown]
# # 8. Details of Datasets from UCI machine learning repositories.

# %%
url_8="https://archive.ics.uci.edu/ml/index.php"

# %%
driver.get(url_8)

# %%
search_1 = driver.find_element(By.XPATH,'/html/body/table[1]/tbody/tr/td[2]/span[2]/a')       # Locating page foe top videos by xpath
search_1.click()

# %%
Dataset_name=[]
Data_type=[]
Task=[]
Attribute_type=[]
No_of_instances=[]
No_of_attribute=[]
Year=[]

# %%
#Scraping Dataset_name details
try:
    for i in driver.find_elements(By.XPATH,"/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[1]/table/tbody/tr/td[2]/p/b/a"):
        Dataset_name.append(i.text)
except NoSuchElementException:
    Dataset_name.append('-')

# %%
len(Dataset_name)
# Out:
# 622

# %%
Dataset_name
# Out:
# ['Abalone',
#  'Adult',
#  'Annealing',
#  'Anonymous Microsoft Web Data',
#  'Arrhythmia',
#  'Artificial Characters',
#  'Audiology (Original)',
#  'Audiology (Standardized)',
#  'Auto MPG',
#  'Automobile',
#  'Badges',
#  'Balance Scale',
#  'Balloons',
#  'Breast Cancer',
#  'Breast Cancer Wisconsin (Original)',
#  'Breast Cancer Wisconsin (Prognostic)',
#  'Breast Cancer Wisconsin (Diagnostic)',
#  'Pittsburgh Bridges',
#  'Car Evaluation',
#  'Census Income',
#  'Chess (King-Rook vs. King-Knight)',
#  'Chess (King-Rook vs. King-Pawn)',
#  'Chess (King-Rook vs. King)',
#  'Chess (Domain Theories)',
#  'Bach Chorales',
#  'Connect-4',
#  'Credit Approval',
#  'Japanese Credit Screening',
#  'Computer Hardware',
#  'Contraceptive Method Choice',
#  'Covertype',
#  'Cylinder Bands',
#  'Dermatology',
#  'Diabetes',
#  'DGP2 - The Second Data Generation Program',
#  'Document Understanding',
#  'EBL Domain Theories',
#  'Echocardiogram',
#  'Ecoli',
#  'Flags',
# ...

# %%
#finding all the datatype tags

try:
    for i in driver.find_elements(By.XPATH,"/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[2]"):
        Data_type.append(i.text)
except NoSuchElementException:
    Data_type.append('-')

# %%
Data_type
# Out:
# ['Data Types',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  ' ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Univariate, Text ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate, Data-Generator ',
#  'Multivariate ',
#  'Multivariate ',
#  'Domain-Theory ',
#  'Univariate, Time-Series ',
#  'Multivariate, Spatial ',
#  'Multivariate ',
#  'Multivariate, Domain-Theory ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate, Time-Series ',
#  'Data-Generator ',
#  ' ',
#  ' ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  ' ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
# ...

# %%
#slicing out the header element
Data_type = Data_type[1:]
Data_type
# Out:
# ['Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  ' ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Univariate, Text ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate, Data-Generator ',
#  'Multivariate ',
#  'Multivariate ',
#  'Domain-Theory ',
#  'Univariate, Time-Series ',
#  'Multivariate, Spatial ',
#  'Multivariate ',
#  'Multivariate, Domain-Theory ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate, Time-Series ',
#  'Data-Generator ',
#  ' ',
#  ' ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  ' ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate, Time-Series ',
# ...

# %%
len(Data_type)
# Out:
# 622

# %%
#finding all the task tags

try:
    for i in driver.find_elements(By.XPATH,"/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[3]"):
        Task.append(i.text)
except NoSuchElementException:
    Task.append('-')

# %%
len(Task)
# Out:
# 623

# %%
#slicing out the header element
Task = Task[1:]
Task
# Out:
# ['Classification ',
#  'Classification ',
#  'Classification ',
#  'Recommender-Systems ',
#  'Classification ',
#  'Classification ',
#  'Classification ',
#  'Classification ',
#  'Regression ',
#  'Regression ',
#  'Classification ',
#  'Classification ',
#  'Classification ',
#  'Classification ',
#  'Classification ',
#  'Classification, Regression ',
#  'Classification ',
#  'Classification ',
#  'Classification ',
#  'Classification ',
#  'Classification ',
#  'Classification ',
#  'Classification ',
#  ' ',
#  ' ',
#  'Classification ',
#  'Classification ',
#  'Classification ',
#  'Regression ',
#  'Classification ',
#  'Classification ',
#  'Classification ',
#  'Classification ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'Classification ',
#  'Classification ',
#  'Classification ',
#  'Function-Learning ',
#  'Classification ',
#  'Classification ',
#  'Classification ',
#  'Classification ',
#  'Classification ',
#  'Classification ',
#  ' ',
#  'Classification ',
# ...

# %%
len(Task)
# Out:
# 622

# %%
#finding all the attribute tags

try:
    for i in driver.find_elements(By.XPATH,"/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[4]"):
        Attribute_type.append(i.text)
except NoSuchElementException:
    Attribute_type.append('-')

# %%
len(Attribute_type)
# Out:
# 623

# %%
#slicing out the header element
Attribute_type = Attribute_type[1:]
Attribute_type
# Out:
# ['Categorical, Integer, Real ',
#  'Categorical, Integer ',
#  'Categorical, Integer, Real ',
#  'Categorical ',
#  'Categorical, Integer, Real ',
#  'Categorical, Integer, Real ',
#  'Categorical ',
#  'Categorical ',
#  'Categorical, Real ',
#  'Categorical, Integer, Real ',
#  ' ',
#  'Categorical ',
#  'Categorical ',
#  'Categorical ',
#  'Integer ',
#  'Real ',
#  'Real ',
#  'Categorical, Integer ',
#  'Categorical ',
#  'Categorical, Integer ',
#  'Categorical, Integer ',
#  'Categorical ',
#  'Categorical, Integer ',
#  ' ',
#  'Categorical, Integer ',
#  'Categorical ',
#  'Categorical, Integer, Real ',
#  'Categorical, Real, Integer ',
#  'Integer ',
#  'Categorical, Integer ',
#  'Categorical, Integer ',
#  'Categorical, Integer, Real ',
#  'Categorical, Integer ',
#  'Categorical, Integer ',
#  'Real ',
#  ' ',
#  ' ',
#  'Categorical, Integer, Real ',
#  'Real ',
#  'Categorical, Integer ',
#  'Real ',
#  'Real ',
#  'Integer ',
#  'Categorical ',
# ...

# %%
len(Attribute_type)
# Out:
# 622

# %%
#finding all the instances tags


try:
    for i in driver.find_elements(By.XPATH,"/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[5]"):
        No_of_instances.append(i.text)
except NoSuchElementException:
    No_of_instances.append('-')

# %%
len(No_of_instances)
# Out:
# 623

# %%
#slicing out the header element
No_of_instances = No_of_instances[1:]
No_of_instances
# Out:
# ['4177 ',
#  '48842 ',
#  '798 ',
#  '37711 ',
#  '452 ',
#  '6000 ',
#  '226 ',
#  '226 ',
#  '398 ',
#  '205 ',
#  '294 ',
#  '625 ',
#  '16 ',
#  '286 ',
#  '699 ',
#  '198 ',
#  '569 ',
#  '108 ',
#  '1728 ',
#  '48842 ',
#  ' ',
#  '3196 ',
#  '28056 ',
#  ' ',
#  '100 ',
#  '67557 ',
#  '690 ',
#  '125 ',
#  '209 ',
#  '1473 ',
#  '581012 ',
#  '512 ',
#  '366 ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '132 ',
#  '336 ',
#  '194 ',
#  '352 ',
#  '214 ',
#  '306 ',
#  '160 ',
#  '303 ',
#  '155 ',
#  '368 ',
#  ' ',
#  '2310 ',
#  '3279 ',
#  '351 ',
#  '150 ',
#  '7797 ',
#  '104 ',
#  '57 ',
#  ' ',
#  '24 ',
#  '20000 ',
#  '345 ',
#  ' ',
#  '32 ',
#  '148 ',
#  '209 ',
#  '528 ',
#  ' ',
#  '106 ',
#  '128 ',
#  '3190 ',
#  '432 ',
#  '202 ',
#  '2000 ',
#  '8124 ',
#  '476 ',
#  '6598 ',
#  '12960 ',
#  ' ',
#  '5473 ',
#  '5620 ',
#  '10992 ',
#  '90 ',
#  '339 ',
#  ' ',
#  ' ',
#  ' ',
#  '167 ',
#  '15 ',
#  '1389 ',
#  '307 ',
#  '47 ',
#  '23 ',
#  '531 ',
#  '4601 ',
# ...

# %%
len(No_of_instances)
# Out:
# 622

# %%
#finding all the number of attributes tags

try:
    for i in driver.find_elements(By.XPATH,"/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[6]"):
        No_of_attribute.append(i.text)
except NoSuchElementException:
    No_of_attribute.append('-')

# %%
len(No_of_attribute)
# Out:
# 623

# %%
#slicing out the header element
No_of_attribute = No_of_attribute[1:]
No_of_attribute
# Out:
# ['8 ',
#  '14 ',
#  '38 ',
#  '294 ',
#  '279 ',
#  '7 ',
#  ' ',
#  '69 ',
#  '8 ',
#  '26 ',
#  '1 ',
#  '4 ',
#  '4 ',
#  '9 ',
#  '10 ',
#  '34 ',
#  '32 ',
#  '13 ',
#  '6 ',
#  '14 ',
#  '22 ',
#  '36 ',
#  '6 ',
#  ' ',
#  '6 ',
#  '42 ',
#  '15 ',
#  ' ',
#  '9 ',
#  '9 ',
#  '54 ',
#  '39 ',
#  '33 ',
#  '20 ',
#  ' ',
#  ' ',
#  ' ',
#  '12 ',
#  '8 ',
#  '30 ',
#  ' ',
#  '10 ',
#  '3 ',
#  '5 ',
#  '75 ',
#  '19 ',
#  '27 ',
#  ' ',
#  '19 ',
#  '1558 ',
#  '34 ',
#  '4 ',
#  '617 ',
#  '12 ',
#  '16 ',
#  '7 ',
#  '4 ',
#  '16 ',
#  '7 ',
#  ' ',
#  '56 ',
#  '18 ',
#  '8 ',
#  '22 ',
#  ' ',
#  '58 ',
#  ' ',
#  '61 ',
#  '7 ',
#  ' ',
#  '649 ',
#  '22 ',
#  '168 ',
#  '168 ',
#  '8 ',
#  ' ',
#  '10 ',
#  '64 ',
#  '16 ',
#  '8 ',
#  '17 ',
#  ' ',
#  ' ',
#  '72 ',
#  '4 ',
#  '6 ',
#  '10 ',
#  '35 ',
#  '35 ',
#  '4 ',
#  '102 ',
#  '57 ',
#  '22 ',
#  '44 ',
#  '45 ',
#  ' ',
#  ' ',
#  '5 ',
#  '9 ',
#  '21 ',
#  '32 ',
#  '17 ',
#  '16 ',
#  '38 ',
#  '21 ',
# ...

# %%
len(No_of_attribute)
# Out:
# 622

# %%
#scraping year from tags

try:
    for i in driver.find_elements(By.XPATH,"/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[7]/p"):
        Year.append(i.text)
except NoSuchElementException:
    Year.append('-')

# %%
len(Year)
# Out:
# 623

# %%
#slicing out the header element
Year = Year[1:]
Year
# Out:
# ['1995 ',
#  '1996 ',
#  ' ',
#  '1998 ',
#  '1998 ',
#  '1992 ',
#  '1987 ',
#  '1992 ',
#  '1993 ',
#  '1987 ',
#  '1994 ',
#  '1994 ',
#  ' ',
#  '1988 ',
#  '1992 ',
#  '1995 ',
#  '1995 ',
#  '1990 ',
#  '1997 ',
#  '1996 ',
#  '1988 ',
#  '1989 ',
#  '1994 ',
#  ' ',
#  ' ',
#  '1995 ',
#  ' ',
#  '1992 ',
#  '1987 ',
#  '1997 ',
#  '1998 ',
#  '1995 ',
#  '1998 ',
#  ' ',
#  ' ',
#  '1994 ',
#  ' ',
#  '1989 ',
#  '1996 ',
#  '1990 ',
#  '1990 ',
#  '1987 ',
#  '1999 ',
#  '1989 ',
#  '1988 ',
#  '1988 ',
#  '1989 ',
#  ' ',
#  '1990 ',
#  '1998 ',
#  '1989 ',
#  '1988 ',
#  '1994 ',
#  '1990 ',
#  '1988 ',
#  '1988 ',
#  '1990 ',
#  '1991 ',
#  '1990 ',
#  ' ',
#  '1992 ',
#  '1988 ',
#  '1990 ',
#  '1996 ',
#  '1995 ',
#  '1990 ',
#  ' ',
#  '1992 ',
#  '1992 ',
#  '1994 ',
#  ' ',
#  '1987 ',
#  '1994 ',
#  '1994 ',
#  '1997 ',
#  '1991 ',
#  '1995 ',
#  '1998 ',
#  '1998 ',
#  '1993 ',
#  '1988 ',
#  ' ',
#  ' ',
#  '1992 ',
#  '1993 ',
#  '1988 ',
#  '1989 ',
#  '1988 ',
# ...

# %%
len(Year)
# Out:
# 622

# %%
#printing lenghts
print(len(Dataset_name),len(Data_type),len(Task),len(Attribute_type),len(No_of_instances),len(No_of_attribute),len(Year))
# Out:
# 622 622 622 622 622 622 622

# %%
len(Data_type)
# Out:
# 622

# %%
#creating a dataframe

uci_datasets=pd.DataFrame({})
uci_datasets['Dataset_name']=Dataset_name
uci_datasets['Data_type']=Data_type
uci_datasets['Task']=Task
uci_datasets['Attribute_type']=Attribute_type
uci_datasets['No_of_instances']=No_of_instances
uci_datasets['No_of_attribute']=No_of_attribute
uci_datasets['Year']=Year

# %%
uci_datasets
# Out:
#                                           Dataset_name  \
# 0                                              Abalone
# 1                                                Adult
# 2                                            Annealing
# 3                         Anonymous Microsoft Web Data
# 4                                           Arrhythmia
# ..                                                 ...
# 617  Influenza outbreak event prediction via Twitte...
# 618                      Turkish Music Emotion Dataset
# 619                      Maternal Health Risk Data Set
# 620                          Room Occupancy Estimation
# 621  Image Recognition Task Execution Times in Mobi...
#
#                       Data_type                  Task  \
# 0                 Multivariate        Classification
# 1                 Multivariate        Classification
# 2                 Multivariate        Classification
# 3                                Recommender-Systems
# ...

# %% [markdown]
# # 7. Scrape the details most watched tv series of all time from imdb.com.¶

# %%
url_7="https://www.imdb.com/list/ls095964455/"

# %%
driver.get(url_7)

# %%
Name=[]
Year_span=[]
Genres=[]
Run_time=[]
Ratings=[]
Votes=[]

# %%
#scraping the Name 

try:
    for i in driver.find_elements(By.XPATH,"//div[@class='lister-item-content']/h3/a"):
        Name.append(i.text)
except NoSuchElementException:
    Name.append('-')

# %%
len(Name)
# Out:
# 100

# %%
#scraping the Year_span 

try:
    for i in driver.find_elements(By.XPATH,"//span[@class='lister-item-year text-muted unbold']"):
        Year_span.append(i.text)
except NoSuchElementException:
    Year_span.append('-')

# %%
len(Year_span)
# Out:
# 100

# %%
#scraping the Genres 

try:
    for i in driver.find_elements(By.XPATH,"//p[@class='text-muted text-small']/span[5]"):
        Genres.append(i.text)
except NoSuchElementException:
    Genres.append('-')

# %%
len(Genres)
# Out:
# 100

# %%
#scraping the Run_time 

try:
    for i in driver.find_elements(By.XPATH,"//p[@class='text-muted text-small']/span[3]"):
        Run_time.append(i.text)
except NoSuchElementException:
    Run_time.append('-')

# %%
len(Run_time)
# Out:
# 100

# %%
#scraping the Ratings 

try:
    for i in driver.find_elements(By.XPATH,"//div[@class='ipl-rating-star small']/span[2]"):
        Ratings.append(i.text)
except NoSuchElementException:
    Ratings.append('-')

# %%
len(Ratings)
# Out:
# 100

# %%
#scraping the Votes 

try:
    for i in driver.find_elements(By.XPATH,"//div[@class='lister-item-content']/p[4]/span[2]"):
        Votes.append(i.text)
except NoSuchElementException:
    Votes.append('-')

# %%
len(Votes)
# Out:
# 100

# %%
TV_Series=pd.DataFrame([])
TV_Series['Name']=Name
TV_Series['Year_span']=Year_span
TV_Series['Run_time']=Run_time
TV_Series['Genres']=Genres
TV_Series['Ratings']=Ratings
TV_Series['Votes']=Votes
TV_Series
# Out:
#                               Name    Year_span Run_time  \
# 0                  Game of Thrones  (2011–2019)   57 min
# 1                  Stranger Things  (2016–2024)   51 min
# 2                 The Walking Dead  (2010–2022)   44 min
# 3                   13 Reasons Why  (2017–2020)   60 min
# 4                          The 100  (2014–2020)   43 min
# ..                             ...          ...      ...
# 95                           Reign  (2013–2017)   42 min
# 96  A Series of Unfortunate Events  (2017–2019)   50 min
# 97                  Criminal Minds     (2005– )   42 min
# 98           Scream: The TV Series  (2015–2019)   45 min
# 99      The Haunting of Hill House       (2018)  572 min
#
#                       Genres Ratings      Votes
# 0   Action, Adventure, Drama     9.2  2,121,576
# 1     Drama, Fantasy, Horror     8.7  1,209,804
# 2    Drama, Horror, Thriller     8.1  1,006,122
# 3   Drama, Mystery, Thriller     7.5    296,917
# ...
